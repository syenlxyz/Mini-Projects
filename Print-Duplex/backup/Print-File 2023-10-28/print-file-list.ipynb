# %%
from pathlib import Path

# %%
folder_path = Path.cwd() / 'MSPO - ERUMAS 2023 DRAFT'
print(folder_path.name)
file_list = list(folder_path.iterdir())
for index, file_path in enumerate(file_list):
    num_file = len(file_list)
    index = str(index+1).zfill(len(str(num_file)))
    print(f'{index}: {file_path.name}')
# Out:
# MSPO - ERUMAS 2023 DRAFT
# 01: 4.1.1 Organizational Chart - ERM 2022-01-03.docx
# 02: 4.1.2 Internal Audit Note - ERM 2022-01-03.docx
# 03: 4.1.2 Internal Audit Plan - ERM 2022-01-03.docx
# 04: 4.1.2 Internal Audit Report - ERM 2022-01-03.docx
# 05: 4.1.2 Internal Audit Summary - ERM 2022-01-03.docx
# 06: 4.1.2 Non-Conformance Report (NCR) - ERM 2022-01-03.docx
# 07: 4.1.3 Management Review Meeting Minutes - ERM 2022-01-04.docx
# 08: 4.1.4 Continual Improvement Plan - ERM 2022-01-03.docx
# 09: 4.2.2 Appointment Letter for Consultation and Communication - ERM 2022-01-03.docx
# 10: 4.2.2 List of Stakeholders - ERM 2022-01-03.docx
# 11: 4.2.3 Appointment Letter for Traceability - ERM 2022-01-03.docx
# 12: 4.2.3 Monthly FFB Production - ERM 2022-12-31.docx
# 13: 4.3.1 Appointment Letter for Regulatory Requirements - ERM 2022-01-03.docx
# 14: 4.3.1 Legal Requirement Register - ERM 2022-01-03.docx
# 15: 4.3.1 Legal Requirement Updates and Implementation - ERM 2022-01-03.docx
# ...

# %%
folder_path = Path.cwd() / 'MSPO - TALU JADI 2023 DRAFT'
print(folder_path.name)
file_list = list(folder_path.iterdir())
for index, file_path in enumerate(file_list):
    num_file = len(file_list)
    index = str(index+1).zfill(len(str(num_file)))
    print(f'{index}: {file_path.name}')
# Out:
# MSPO - TALU JADI 2023 DRAFT
# 01: 4.1.1 Organizational Chart - TJSB 2022-01-03.docx
# 02: 4.1.2 Internal Audit Checklist - TJSB 2022-01-03.docx
# 03: 4.1.2 Internal Audit Note - TJSB 2022-01-03.docx
# 04: 4.1.2 Internal Audit Plan - TJSB 2022-01-03.docx
# 05: 4.1.2 Internal Audit Report - TJSB 2022-01-03.docx
# 06: 4.1.2 Internal Audit Summary - TJSB 2022-01-03.docx
# 07: 4.1.2 Non-Conformance Report (NCR) - TJSB 2022-01-03.docx
# 08: 4.1.3 Management Review Meeting Minutes - TJSB 2021-01-04.docx
# 09: 4.1.4 Continual Improvement Plan - TJSB 2022-01-05.docx
# 10: 4.2.2 Appointment Letter for Consultation and Communication - TJSB 2022-01-03.docx
# 11: 4.2.2 List of Stakeholders - TJSB 2022-01-03.docx
# 12: 4.2.3 Appointment Letter for Traceability - TJSB 2022-01-03.docx
# 13: 4.2.3 Monthly FFB Production - TJSB 2022-12-31.docx
# 14: 4.3.1 Appointment Letter for Regulatory Requirements - TJSB 2022-01-03.docx
# 15: 4.3.1 Legal Requirement Register - TJSB 2022-01-03.docx
# ...

# %%
folder_path = Path.cwd() / 'MSPO - TJPLANT 2023 DRAFT'
print(folder_path.name)
file_list = list(folder_path.iterdir())
for index, file_path in enumerate(file_list):
    num_file = len(file_list)
    index = str(index+1).zfill(len(str(num_file)))
    print(f'{index}: {file_path.name}')
# Out:
# MSPO - TJPLANT 2023 DRAFT
# 01: 4.1.1 Organizational Chart - TJP 2023-01-02.docx
# 02: 4.1.2 Continual Improvement Plan - TJP 2023-01-02.docx
# 03: 4.2.1 Appointment Letter for Traceability - TJP 2023-01-02.docx
# 04: 4.2.1 Monthly FFB Production - TJP 2023-09-30.docx
# 05: 4.3.1 Appointment Letter for Regulatory Requirements - TJP 2023-01-02.docx
# 06: 4.3.1 List of Legal Documents - TJP 2023-01-02.docx
# 07: 4.4.1 Appointment Letter for Complaints and Grievances - TJP 2023-01-02.docx
# 08: 4.4.2 Appointment Letter for Employees Safety and Health - TJP 2023-01-02.docx
# 09: 4.4.2 Chemical Record - TJP 2023-01-02.docx
# 10: 4.4.2 Covid-19 Prevention Procedure - TJP 2023-01-02.docx
# 11: 4.4.2 PPE Issuance Record - TJP 2023-01-02.docx
# 12: 4.4.4 Training Programme - TJP 2023-01-02.docx
# 13: 4.5.1 Appointment Letter for Environmental Management Plan - ERM 2023-01-02.docx
# 14: 4.5.1 Plantation Environmental Plan - TJP 2023-01-02.docx
# ...
